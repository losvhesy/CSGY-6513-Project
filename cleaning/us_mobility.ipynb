# %%
import pandas as pd
import numpy as np

# %%
filename_2020 = "/home/jnzs1836/Code/CSGY-6513/ProjectData/Region_Mobility_Report_CSVs/2020_US_Region_Mobility_Report.csv"
filename_2021 = "/home/jnzs1836/Code/CSGY-6513/ProjectData/Region_Mobility_Report_CSVs/2021_US_Region_Mobility_Report.csv"

# %%
chunksize = 1000
chunks_2020 = pd.read_csv(filename_2020, chunksize=chunksize)
chunks_2021 = pd.read_csv(filename_2021, chunksize=chunksize)
raw_df_2020 = pd.concat(chunks_2020)
raw_df_2021 = pd.concat(chunks_2021)

# %%
def process_df(df):
    tmp = df[pd.isnull(df['sub_region_2'])]
    tmp = tmp[~pd.isnull(tmp['sub_region_1'])]
    return tmp

df_2020 = process_df(raw_df_2020)
df_2021 = process_df(raw_df_2021)

# %%
df = pd.concat([df_2020, df_2021])

# %%
tmp = df[df['sub_region_1']=="Alabama"]
tmp
# Out:
#     country_region_code country_region sub_region_1 sub_region_2  metro_area  \
# 321                  US  United States      Alabama          NaN         NaN
# 322                  US  United States      Alabama          NaN         NaN
# 323                  US  United States      Alabama          NaN         NaN
# 324                  US  United States      Alabama          NaN         NaN
# 325                  US  United States      Alabama          NaN         NaN
# ..                  ...            ...          ...          ...         ...
# 159                  US  United States      Alabama          NaN         NaN
# 160                  US  United States      Alabama          NaN         NaN
# 161                  US  United States      Alabama          NaN         NaN
# 162                  US  United States      Alabama          NaN         NaN
# 163                  US  United States      Alabama          NaN         NaN
#
# ...

# %%
tmp = df[pd.isnull(df['sub_region_2'])]

# %%
tmp = tmp[~pd.isnull(tmp['sub_region_1'])]

# %%
403 * 51
# Out:
# 20553

# %%
df_2020[pd.isnull(df_2020['transit_stations_percent_change_from_baseline'])]
# Out:
#        country_region_code country_region   sub_region_1 sub_region_2  \
# 20464                   US  United States         Alaska          NaN
# 20465                   US  United States         Alaska          NaN
# 20466                   US  United States         Alaska          NaN
# 20467                   US  United States         Alaska          NaN
# 20468                   US  United States         Alaska          NaN
# ...                    ...            ...            ...          ...
# 718841                  US  United States        Vermont          NaN
# 772059                  US  United States  West Virginia          NaN
# 772066                  US  United States  West Virginia          NaN
# 772073                  US  United States  West Virginia          NaN
# 806323                  US  United States        Wyoming          NaN
#
#         metro_area iso_3166_2_code  census_fips_code  \
# 20464          NaN           US-AK               NaN
# ...

# %%
df.to_csv("./state_mobility.csv")

# %%
raw_df_2021
# Out:
#        country_region_code country_region sub_region_1   sub_region_2  \
# 0                       US  United States          NaN            NaN
# 1                       US  United States          NaN            NaN
# 2                       US  United States          NaN            NaN
# 3                       US  United States          NaN            NaN
# 4                       US  United States          NaN            NaN
# ...                    ...            ...          ...            ...
# 213670                  US  United States      Wyoming  Weston County
# 213671                  US  United States      Wyoming  Weston County
# 213672                  US  United States      Wyoming  Weston County
# 213673                  US  United States      Wyoming  Weston County
# 213674                  US  United States      Wyoming  Weston County
#
#         metro_area iso_3166_2_code  census_fips_code  \
# 0              NaN             NaN               NaN
# ...
