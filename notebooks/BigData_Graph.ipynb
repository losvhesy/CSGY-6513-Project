# %%
from pandas import DataFrame
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from datetime import datetime
import warnings
warnings.filterwarnings('ignore')

# %%
states = ["Alabama", "Alaska", "Arizona", "Arkansas", "California", "Colorado", "Connecticut", \
          "Delaware", "Florida", "Georgia", "Hawaii", "Idaho", "Illinois", "Indiana", "Iowa", "Kansas",\
          "Kentucky", "Louisiana", "Maine", "Maryland", "Massachusetts", "Michigan", "Minnesota", "Mississippi", \
          "Missouri", "Montana", "Nebraska", "Nevada", "New Hampshire", "New Jersey", "New Mexico", "New York", \
          "North Carolina", "North Dakota", "Ohio", "Oklahoma", "Oregon", "Pennsylvania", "Rhode Island", \
          "South Carolina", "South Dakota", "Tennessee", "Texas", "Utah", "Vermont", "Virginia", "Washington", \
          "West Virginia", "Wisconsin", "Wyoming", "District of Columbia"]
len(states)
# Out:
# 51

# %%
state = input("Enter a from the list above: ")
# Out:
# Enter a from the list above: Newyork

# %%
while True:
    if state not in states:
        state = input("Plz enter again: ")
    else:
        break
print("You entered " + state)
# Out:
# Plz enter again: New York
# You entered New York

# %%
from Analysis_for_states import get_line_chart
get_line_chart( "Integrated.csv", state)
# Out:
# Seperate Line Charts:
# Combined Line Chart with 2 y axis:
#     Red:    retail_and_recreation_percent_change_from_baseline, y_axis on the left
#     blue:   grocery_and_pharmacy_percent_change_from_baseline,  y_axis on the left
#     brown:  transit_stations_percent_change_from_baseline,      y_axis on the left
#     green:  workplaces_percent_change_from_baseline,            y_axis on the left
#     orange: residential_percent_change_from_baseline,           y_axis on the left
#     black:  new cases,                                          y_axis on the right
#
# Y_label for the y_axis on the left is percent change from baseline
# Y_label for the y_axis on the right is number of cases

# %%
from Analysis_for_states import get_bar_chart
get_bar_chart( "integrated.csv", state)

# %%
from Analysis_for_states import get_weekly
get_weekly( "integrated.csv", state, 7)
# Out:
# Combined Line Chart with 2 y axis:
#     Red:    retail_and_recreation_percent_change_from_baseline, y_axis on the left
#     blue:   grocery_and_pharmacy_percent_change_from_baseline,  y_axis on the left
#     brown:  transit_stations_percent_change_from_baseline,      y_axis on the left
#     green:  workplaces_percent_change_from_baseline,            y_axis on the left
#     orange: residential_percent_change_from_baseline,           y_axis on the left
#     black:  new cases,                                          y_axis on the right
#
# X_label is number of weeks from baseline
# Y_label for the y_axis on the left is percent change from baseline
# Y_label for the y_axis on the right is number of cases
